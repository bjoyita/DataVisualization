# %% [markdown]
# <a href="https://colab.research.google.com/github/bjoyita/DataVisualization/blob/main/Correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns

# %% [markdown]
# **Loading data**
# *Room temperature Thermoelectric proproperties of 204 compositions*

# %%
ds = pd.read_csv('TE_props_correlation1.csv')
ds
# Out:
#      Seebeck  kappa    sigma       ZT
# 0       -100  2.513   49.200  0.00588
# 1        -91  2.268  113.000  0.01000
# 2       -180  2.500   50.000  0.02000
# 3       -162  1.787   67.300  0.03000
# 4       -104  2.850   68.800  0.00787
# ..       ...    ...      ...      ...
# 199      -61  5.200  472.000  0.01000
# 200     -178  7.250  821.000  0.11000
# 201     -191  5.690   21.100  0.00405
# 202     -318  4.590    7.843  0.00518
# 203     -226  2.860    3.704  0.00198
#
# [204 rows x 4 columns]

# %%
df=pd.DataFrame(ds)

# %% [markdown]
# **Converting to dataframe**

# %%
df
# Out:
#      Seebeck  kappa    sigma       ZT
# 0       -100  2.513   49.200  0.00588
# 1        -91  2.268  113.000  0.01000
# 2       -180  2.500   50.000  0.02000
# 3       -162  1.787   67.300  0.03000
# 4       -104  2.850   68.800  0.00787
# ..       ...    ...      ...      ...
# 199      -61  5.200  472.000  0.01000
# 200     -178  7.250  821.000  0.11000
# 201     -191  5.690   21.100  0.00405
# 202     -318  4.590    7.843  0.00518
# 203     -226  2.860    3.704  0.00198
#
# [204 rows x 4 columns]

# %% [markdown]
# **PANDAS: Correlation Matrix**

# %%
matrix= df.corr()
matrix
# Out:
#           Seebeck     kappa     sigma        ZT
# Seebeck  1.000000 -0.246208 -0.159189  0.015533
# kappa   -0.246208  1.000000  0.037781 -0.185458
# sigma   -0.159189  0.037781  1.000000 -0.017626
# ZT       0.015533 -0.185458 -0.017626  1.000000

# %% [markdown]
# With the background_gradient function, we could color the data frame as a gradient. The color would depend on the cmap parameter where the parameter is accepting colormaps from the matplotlib library.

# %%
matrix.style.background_gradient(cmap='icefire')
# Out:
# <style type="text/css">
# #T_357c4_row0_col0, #T_357c4_row1_col1, #T_357c4_row2_col2, #T_357c4_row3_col3 {
#   background-color: #ffd4ac;
#   color: #000000;
# }
# #T_357c4_row0_col1, #T_357c4_row0_col2, #T_357c4_row1_col0, #T_357c4_row1_col3 {
#   background-color: #bde7db;
#   color: #000000;
# }
# #T_357c4_row0_col3, #T_357c4_row1_col2 {
#   background-color: #4596ce;
#   color: #f1f1f1;
# }
# #T_357c4_row2_col0 {
#   background-color: #8dc6d0;
#   color: #000000;
# }
# #T_357c4_row2_col1 {
#   background-color: #3975cf;
#   color: #f1f1f1;
# }
# #T_357c4_row2_col3 {
#   background-color: #55a3cd;
#   color: #f1f1f1;
# }
# #T_357c4_row3_col0 {
#   background-color: #3781d0;
#   color: #f1f1f1;
# }
# #T_357c4_row3_col1 {
#   background-color: #9bcfd3;
#   color: #000000;
# }
# #T_357c4_row3_col2 {
#   background-color: #63adcd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_357c4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# **Visulaization using Seaborn**

# %% [markdown]
# **Annotated Heatmap displaying the correlations between the properties**
# **bold text**

# %%
heatmap_seaborn = sns.heatmap(matrix, annot=True, linewidth = 0.5, linecolor='black', cmap='rocket')

# %% [markdown]
# **Saving the Heatmap**

# %%
plt.savefig('heatmap_seaborn.png', dpi=400)

# %% [markdown]
# **Visualization: Plotly express**
# **Plotly: plotly.express**
# https://plotly.com/python/plotly-express/

# %%
# !pip install Plotly

# %%
import plotly.express as px

# %%
fig = px.imshow(matrix, text_auto=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
